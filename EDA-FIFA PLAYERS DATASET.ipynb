# %%
import pandas as pd
import numpy as nb

# %%
df=pd.read_csv("C:/Users/hp/OneDrive/Desktop/data science/csv/fifa_data.csv")

# %%
df
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 0               0  158023            L. Messi   31
# 1               1   20801   Cristiano Ronaldo   33
# 2               2  190871           Neymar Jr   26
# 3               3  193080              De Gea   27
# 4               4  192985        K. De Bruyne   27
# ...           ...     ...                 ...  ...
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1       https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2      https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3      https://cdn.sofifa.org/players/4/19/193080.png       Spain
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.Nationality.value_counts()
# Out:
# Nationality
# England                 1662
# Germany                 1198
# Spain                   1072
# Argentina                937
# France                   914
#                         ...
# New Caledonia              1
# Fiji                       1
# São Tomé & Príncipe        1
# United Arab Emirates       1
# Botswana                   1
# Name: count, Length: 164, dtype: int64

# %%
big=df.Nationality.value_counts()

# %%
print(f'{big.idxmax()} is the country has the most number of players')
# Out:
# England is the country has the most number of players

# %% [markdown]
# # value_counts helps us to find the total number of players in each country
# # here country England has the most number of players

# %%
import matplotlib.pyplot as plt

# %%
s1=df.Nationality.value_counts()

# %%
s1.head(5)
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
s2=s1[0:5]

# %%
s2
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,9),dpi=100)
s2.plot(kind='bar',color='red',width=0.4,edgecolor='blue')
plt.xlabel("Name of country")
plt.ylabel("Number of players")
plt.title("TOP 5 COUNTRIES WITH THE MOST NUMBER OF PLAYERS",color='maroon')
# Out:
# Text(0.5, 1.0, 'TOP 5 COUNTRIES WITH THE MOST NUMBER OF PLAYERS')

# %% [markdown]
# # bar chart of 5 top countries with the most number of players

# %%
df.Wage.value_counts()
# Out:
# Wage
# €1K      4900
# €2K      2827
# €3K      1857
# €4K      1255
# €5K       869
#          ...
# €190K       1
# €235K       1
# €93K        1
# €405K       1
# €565K       1
# Name: count, Length: 144, dtype: int64

# %%
df.value_counts(['Wage','Name'])
df1=df.sort_values(by='Wage',ascending=True)
df_top=df_sorted[['Wage','Name']]
df_top.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 df.value_counts(['Wage','Name'])
#       2 df1=df.sort_values(by='Wage',ascending=True)
# ----> 3 df_top=df_sorted[['Wage','Name']]
#       4 df_top.head(5)
#
# NameError: name 'df_sorted' is not defined

# %%
#df['Wage']=df['Wage'].replace('[$k]').astype(float)
df1=df.sort_values(by='Wage',ascending=False)
df_top=df_sorted[['Name','Wage']]
df_top.head(5)

# %%
top_twenty_val = df[['Name','Wage']].nlargest(20, 'Wage')
top_twenty_val

# %%
df.sort_values(by='Height',ascending=False)
#[['Name','Height']].head(30)
# Out:
#        Unnamed: 0      ID                 Name  Age  \
# 11614       11614  199321              T. Holý   26
# 17927       17927  243796            D. Hodzic   22
# 11903       11903  243675          K. Scherpen   18
# 17694       17694  241870             M. Casey   18
# 4189         4189  224836  V. Milinković-Savić   21
# ...           ...     ...                  ...  ...
# 13279       13279  239679         P. Mazzocchi   22
# 13280       13280  244543            Y. Ammour   19
# 13281       13281  212800       Jwa Joon Hyeop   27
# 13282       13282  231232           O. Marrufo   25
# 13283       13283  232256          Han Pengfei   25
#
#                                                 Photo     Nationality  \
# 11614  https://cdn.sofifa.org/players/4/19/199321.png  Czech Republic
# 17927  https://cdn.sofifa.org/players/4/19/243796.png         Croatia
# 11903  https://cdn.sofifa.org/players/4/19/243675.png     Netherlands
# ...

# %%
c1=df.Club.value_counts()
c1

# %% [markdown]
# # TOP CLUBS WITH MAXIMUM NUMBER OF PLAYERS

# %%
c1.head(26)

# %%
f1=df.value_counts(['Preferred Foot'])
f1
